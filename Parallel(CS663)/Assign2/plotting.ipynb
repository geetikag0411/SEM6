# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# Data to be plotted
a_8_4096_leader = [7.2112, 7.42113, 7.20782, 7.18189, 7.44391 ]
a_8_4096_without = [7.81934, 7.38712, 7.77812, 7.61276, 8.06745]

a_12_4096_leader = [7.29865, 7.41782,7.54912, 7.41892, 7.39823]
a_12_4096_without = [7.62094, 7.91983, 8.03812, 7.71294, 8.14231]

a_8_8192_leader = [27.62853, 27.19835, 28.83421, 26.98241, 27.23845]
a_8_8192_without = [30.73923, 30.16482, 30.85296, 31.20946, 30.17305]

a_12_8192_leader = [27.81532, 28.69238, 29.10934, 26.81943, 28.3013 ]
a_12_8192_without = [31.58423, 30.31097, 31.99147, 31.90842, 30.98310]



# Combine the data into a list of lists
data = [a_8_4096_leader,a_8_4096_without, a_12_4096_leader, a_12_4096_without, a_8_8192_leader, a_8_8192_without,a_12_8192_leader , a_12_8192_without  ]

# Create labels for x-axis
labels = ['8_4096_l','8_4096_w', '12_4096_l', '12_4096_w', '8_8192_l', '8_8192_w','12_8192_l' , '12_8192_w' ]

# Create boxplots
fig, ax = plt.subplots(figsize=(10, 6))
plt.boxplot(data, labels=labels)

# Add title and labels
plt.title('Timing plots')
plt.xlabel('processes,data size(sqrt), with or without leader')
plt.ylabel('Time (s)')
ax.yaxis.set_minor_locator(ticker.AutoMinorLocator(5))
ax.yaxis.grid(which="both", linewidth=0.25)
# Show plot
plt.grid(True)
plt.show()
